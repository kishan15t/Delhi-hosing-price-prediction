# %% [markdown]
# ## Delhi housing price predication

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\kisha\\OneDrive\\Desktop\\MagicBricks.csv")
df.head()
# Out:
#     Area  BHK  Bathroom      Furnishing  \
# 0  800.0    3       2.0  Semi-Furnished
# 1  750.0    2       2.0  Semi-Furnished
# 2  950.0    2       2.0       Furnished
# 3  600.0    2       2.0  Semi-Furnished
# 4  650.0    2       2.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 0                                   Rohini Sector 25      1.0   6500000
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
#
#           Status   Transaction           Type  Per_Sqft
# 0  Ready_to_move  New_Property  Builder_Floor       NaN
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment    6667.0
# 3  Ready_to_move        Resale  Builder_Floor    6667.0
# ...

# %% [markdown]
# #### Fristly i imported my file then i started my data cleaning process began

# %%
df.nunique()
# Out:
# Area           315
# BHK              8
# Bathroom         7
# Furnishing       3
# Locality       365
# Parking          9
# Price          284
# Status           2
# Transaction      2
# Type             2
# Per_Sqft       251
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         2
# Furnishing       5
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# dtype: int64

# %%
df.isna().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         2
# Furnishing       5
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# dtype: int64

# %%
round(df.Parking.mean(),2)
# Out:
# 1.94

# %%
df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         2
# Furnishing       5
# Locality         0
# Parking         33
# Price            0
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# dtype: int64

# %%
df['Bathroom'] = df['Bathroom'].fillna(1)

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#      Area  BHK  Bathroom      Furnishing  \
# 1   750.0    2       2.0  Semi-Furnished
# 2   950.0    2       2.0       Furnished
# 3   600.0    2       2.0  Semi-Furnished
# 4   650.0    2       2.0  Semi-Furnished
# 5  1300.0    4       3.0  Semi-Furnished
#
#                                             Locality  Parking     Price  \
# 1             J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                   Rohini Sector 24      1.0   4200000
# 4  Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
# 5                                   Rohini Sector 24      1.0  15500000
#
#           Status   Transaction           Type  Per_Sqft
# 1  Ready_to_move  New_Property      Apartment    6667.0
# 2  Ready_to_move        Resale      Apartment    6667.0
# 3  Ready_to_move        Resale  Builder_Floor    6667.0
# ...

# %%
df.isnull().sum()
# Out:
# Area           0
# BHK            0
# Bathroom       0
# Furnishing     0
# Locality       0
# Parking        0
# Price          0
# Status         0
# Transaction    0
# Type           0
# Per_Sqft       0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.groupby('Furnishing')['Furnishing'].value_counts()
# Out:
# Furnishing
# Furnished         141
# Semi-Furnished    563
# Unfurnished       301
# Name: count, dtype: int64

# %%
plt.pie(df.groupby('Furnishing')['Furnishing'].value_counts(),labels=['Furnished','Semi-Furnished','Unfurnished'])
plt.show()

# %% [markdown]
# #### I ploted furnishing column my data on pie chat to see how furnishing columns look like

# %%
df.groupby('Locality')['Locality'].value_counts()
# Out:
# Locality
# APL Builder Floor, Greater Kailash 1                                                                                                                                                                                                                                                                                                       2
# Abhimanyu Apartments, Vasundhara Enclave                                                                                                                                                                                                                                                                                                   1
# ...

# %%
plt.hist(df.groupby('Locality')['Locality'].value_counts(),label =True)
# Out:
# (array([237.,  28.,  15.,   7.,   5.,   3.,   3.,   2.,   3.,   1.]),
#  array([ 1.,  4.,  7., 10., 13., 16., 19., 22., 25., 28., 31.]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()

# %%
df.nunique()
# Out:
# Area           289
# BHK              7
# Bathroom         7
# Furnishing       3
# Locality       304
# Parking          8
# Price          258
# Status           2
# Transaction      2
# Type             2
# Per_Sqft       246
# dtype: int64

# %%
df['Status'] = label.fit_transform(df.Status)
df['Transaction'] = label.fit_transform(df.Transaction)
df['Type'] = label.fit_transform(df.Type)
df['Furnishing'] = label.fit_transform(df.Furnishing)

# %% [markdown]
# #### so here i converted my all string column into intr through label encoding

# %%
df.sample(5)
# Out:
#         Area  BHK  Bathroom  Furnishing  \
# 1240  1000.0    2       2.0           1
# 557   2250.0    4       4.0           1
# 355    700.0    2       1.0           0
# 706   1400.0    2       2.0           1
# 204   2300.0    4       4.0           1
#
#                                     Locality  Parking     Price  Status  \
# 1240                       Chittaranjan Park      1.0   7500000       1
# 557                                    Saket      2.0  33700000       1
# 355                   Yamuna Vihar, Shahdara      2.0  16000000       1
# 706                                Alaknanda      2.0  14000000       1
# 204   J R Designers Floors, Rohini Sector 24      1.0  24500000       1
#
#       Transaction  Type  Per_Sqft
# 1240            1     0   18333.0
# 557             1     1   14705.0
# 355             0     1   22857.0
# 706             1     0   12500.0
# 204             0     1    6714.0

# %%
df.sample(10)
# Out:
#         Area  BHK  Bathroom  Furnishing                        Locality  \
# 401    495.0    2       2.0           1                Uttam Nagar West
# 355    700.0    2       1.0           0          Yamuna Vihar, Shahdara
# 521   2210.0    4       3.0           1            Sukhdev Vihar, Okhla
# 950    800.0    2       2.0           1  Dilshad Colony, Dilshad Garden
# 331    540.0    2       1.0           0          Yamuna Vihar, Shahdara
# 704   1100.0    2       2.0           2                       Alaknanda
# 857    420.0    1       1.0           2          Mahavir Enclave Part 1
# 828    540.0    1       1.0           2                        Mehrauli
# 1239  1450.0    3       3.0           1               Chittaranjan Park
# 172   2170.0    4       4.0           2                Rohini Sector 23
#
#       Parking     Price  Status  Transaction  Type  Per_Sqft
# 401       1.0   2150000       1            0     1    6111.0
# ...

# %%
dumies = pd.get_dummies(df.Locality) 
### Here i made all rows of locality columns into dummies by callling pandas get dummies code

# %% [markdown]
# ##### did some feautre engineering

# %%
min_thresold = df['Price'].quantile(0.01)

# %%
df[(df['Price']<min_thresold)]
# Out:
#           Area  BHK  Bathroom  Furnishing                    Locality  \
# 158   270.0000    2       1.0           1          Budh Vihar Phase 1
# 834   405.0000    1       1.0           2                    Mehrauli
# 886   350.0000    1       1.0           2                      Narela
# 893   198.0000    1       1.0           0            Narela Sector A5
# 894  4900.0000    1       1.0           2       DDA Lig Flats, Narela
# 895  2077.4327    1       1.0           2  DDA Flats Pocket 3, Narela
#
#      Parking    Price  Status  Transaction  Type  Per_Sqft
# 158      1.0  1400000       1            1     0    5185.0
# 834      1.0  1200000       1            1     1    2963.0
# 886      1.0  1490000       1            0     0    4270.0
# 893      1.0  1000000       1            1     0    5051.0
# 894      1.0  1000000       1            0     0    5051.0
# 895      1.0  1000000       1            1     1    5051.0

# %%
df1  = df.copy()

# %%
df2 = pd.concat([df1,dumies],axis='columns')
### concated my dummies columns and my data frame

# %%
df2
# Out:
#          Area  BHK  Bathroom  Furnishing  \
# 1       750.0    2       2.0           1
# 2       950.0    2       2.0           0
# 3       600.0    2       2.0           1
# 4       650.0    2       2.0           1
# 5      1300.0    4       3.0           1
# ...       ...  ...       ...         ...
# 1254   4118.0    4       5.0           2
# 1255   1050.0    3       2.0           1
# 1256    875.0    3       3.0           1
# 1257    990.0    2       2.0           2
# 1258  11050.0    3       3.0           2
#
#                                                Locality  Parking     Price  \
# 1                J R Designers Floors, Rohini Sector 24      1.0   5000000
# 2                   Citizen Apartment, Rohini Sector 13      1.0  15500000
# 3                                      Rohini Sector 24      1.0   4200000
# 4     Rohini Sector 24 carpet area 650 sqft status R...      1.0   6200000
# 5                                      Rohini Sector 24      1.0  15500000
# ...

# %% [markdown]
# #### Build my model

# %%
from sklearn.linear_model import LinearRegression
lg = LinearRegression()

# %%
x = df2['Price']

# %%
y = df2.drop(['Locality','Price','Narela'],axis =1)

# %%
from sklearn.model_selection import train_test_split

# %%
 X_train, X_test, y_train, y_test = train_test_split(y,x,test_size=0.3)
# divided my data sets into train data and test data

# %%
lg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lg.score(X_test,y_test)
# Out:
# -6967074695996291.0

# %%
from sklearn.model_selection import cross_val_score

# %%
lg.fit(y,x)
# Out:
# LinearRegression()

# %%
lg.score(y,x)
# Out:
# 0.8900780837995221

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in y]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
